# %%
#1 sum of list
numbers=[23,24,25,26]
print("SUM OF ALL THE NUMBERS:",sum(numbers))
# Out:
# SUM OF ALL THE NUMBERS: 98

# %%
#1  sum for two list
numbers=[23,24,25,26]
num=[1,2,3,4]
addition=numbers+num
print(addition)
print(sum(numbers+num))
print(sum(addition))
# Out:
# [23, 24, 25, 26, 1, 2, 3, 4]
# 108
# 108

# %%
import numpy as np 
numbers=[23,24,25,26]
num=[1,2,3,4]
np.add(numbers,num)
# Out:
# array([24, 26, 28, 30])

# %%
#2 multiply
import numpy as np
numbers=[23,24,25,26]
num=[1,2,3,4]
np.multiply(numbers,num)
# Out:
# array([ 23,  48,  75, 104])

# %%
#3
numbers=[23,24,25,26]
print("GREATEST NUMBER:",max(numbers))
print("SMALLEST NUMBER:",min(numbers))
# Out:
# GREATEST NUMBER: 26
# SMALLEST NUMBER: 23

# %%
#4
letters=['a','b','c','d','e']
print(letters.sort(reverse=True))
print(letters)
# Out:
# None
# ['e', 'd', 'c', 'b', 'a']

# %%
#5
alpha=[6,7,8,6,6,6]
updated_list=list(set(alpha))
print(updated_list)
# Out:
# [8, 6, 7]

# %%
#6
company=["apple","lenovo","google","samsung"]
company1=company.copy()
print(company1)
# Out:
# ['apple', 'lenovo', 'google', 'samsung']

# %%
#7 count
alphabet=['a','b','c','a','a','a']
print(alphabet.count('a'))
# Out:
# 4

# %%
# 8 sort in ascen
company=["apple","lenovo","google","samsung"]
company.sort()
print(company)
# Out:
# ['apple', 'google', 'lenovo', 'samsung']

# %%
# 9 combine
x=["hello"]
y=["world"]
print(x+y)
# Out:
# ['hello', 'world']

# %%
x=(["hello"])
y=(["world"])
print(x+y)
# Out:
# ['hello', 'world']

# %%
#11
square=np.array([1,2,3,4])
square**2
# Out:
# array([ 1,  4,  9, 16])

# %%
# 12 nested list
x=np.array([[1,2,3,4],[5,6,7,8]])
x
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
#13
empty=np.empty([])
print(empty)
# Out:
# 5e-324

# %%
#14
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
common_items = list(set(list1) & set(list2))
print(common_items)
# Out:
# [4, 5]

# %%
#15 replace the last element
last_element=[23,24,25,26,27]
last_element[4]=30
print(last_element)
# Out:
# [23, 24, 25, 26, 30]
