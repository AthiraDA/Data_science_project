# %%
a=10
b=15
if a > 5 and b>10:
    print('both a and b satisfy')
# Out:
# both a and b satisfy

# %%
flag= False
if not flag:
    print("flag is false")
# Out:
# flag is false

# %%
flag= False
slag=True
if not slag:
    print("flag is false")
else:
    print("slag")
# Out:
# slag

# %%
score=85
attendance=90
if (score > 80 and attendance > 85) or score > 90:
    print("criteria met for bonus")
# Out:
# criteria met for bonus

# %%
score=85
attendance=90
if (score > 80 and attendance > 85) and score > 90:
    print("criteria met for bonus")
else:
    print('criteria not met for bonu')
# Out:
# criteria not met for bonu

# %%
#  if condition on 15 nov
